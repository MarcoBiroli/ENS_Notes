# %% [markdown]
# # 1- Class Activation Map with convolutions
#
# In this firt part, we will code class activation map as described in the paper [Learning Deep Features for Discriminative Localization](http://cnnlocalization.csail.mit.edu/)
#
# There is a GitHub repo associated with the paper:
# https://github.com/zhoubolei/CAM
#
# And even a demo in PyTorch:
# https://github.com/zhoubolei/CAM/blob/master/pytorch_CAM.py
#
# The code below is adapted from this demo but we will not use hooks only convolutions...

# %%
import io
import requests
from PIL import Image
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.nn import functional as F
import torch.optim as optim
import numpy as np
import cv2
import pdb
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow


# input image
LABELS_URL = 'https://s3.amazonaws.com/outcome-blog/imagenet/labels.json'
IMG_URL = 'http://media.mlive.com/news_impact/photo/9933031-large.jpg'

# %% [markdown]
# As in the demo, we will use the Resnet18 architecture. In order to get CAM, we need to transform this network in a fully convolutional network: at all layers, we need to deal with images, i.e. with a shape $\text{Number of channels} \times W\times H$ . In particular, we are interested in the last images as shown here:
# ![](https://camo.githubusercontent.com/fb9a2d0813e5d530f49fa074c378cf83959346f7/687474703a2f2f636e6e6c6f63616c697a6174696f6e2e637361696c2e6d69742e6564752f6672616d65776f726b2e6a7067)
#
# As we deal with a Resnet18 architecture, the image obtained before applying the `AdaptiveAvgPool2d` has size $512\times 7 \times 7$ if the input has size $3\times 224\times 224 $:
# ![resnet_Archi](https://pytorch.org/assets/images/resnet.png)
#
# A- The first thing, you will need to do is 'removing' the last layers of the resnet18 model which are called `(avgpool)` and `(fc)`. Check that for an original image of size $3\times 224\times 224 $, you obtain an image of size $512\times 7\times 7$.
#
# B- Then you need to retrieve the weights (and bias) of the `fc` layer, i.e. a matrix of size $1000\times 512$ transforming a vector of size 512 into a vector of size 1000 to make the prediction. Then you need to use these weights and bias to apply it pixelwise in order to transform your $512\times 7\times 7$ image into a $1000\times 7\times 7$ output (Hint: use a convolution). You can interpret this output as follows: `output[i,j,k]` is the logit for 'pixel' `[j,k]` for being of class `i`.
#
# C- From this $1000\times 7\times 7$ output, check that you can retrieve the original output given by the `resnet18` by using an `AdaptiveAvgPool2d`. Can you understand why this is true?
#
# D- In addition, you can construct the Class Activation Map. Draw the activation map for the class mountain bike, for the class lakeside.

# %% [markdown]
# ## Validation:
# 1. make sure that when running your notebook, you display both CAM for the class mountain bike and for the class lakeside.
# 2. for question B above, what convolution did you use? Your answer, i.e. the name of the Pytorch layer with the correct parameters (in_channel,kernel...) here:
#
# I used the following: Conv2D(512, 1000, 1) i.e. a 2D Convolutional layer with input 512 output 1000 and a square kernel of dimension (1, 1).
#
# 3. your short explanation of why your network gives the same predicition as the original `resnet18`:
#
# Our network is simply a sort of re-statement of the `resnet18` by permutting the last two layers and removing the `AdaptiveAvgPool2D`. Hence one can expect to obtain the same output after applying `AdaptiveAvgPool2D` on the output of the CNN.
#
# 4. Is your network working on an image which is not of size $224\times 224$, i.e. without resizing? and what about `resnet18`? Explain why?
#
# `resnet18` can handle different sized images through its `AdaptiveAvgPool2D` layer which however is not a convolutional layer and hence is not part of our network.

# %%
net = models.resnet18(pretrained=True)

# %%
print(net)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
x = torch.randn(5, 3, 224, 224)
y = net(x)
y.shape
# Out:
# torch.Size([5, 1000])

# %%
n_mean = [0.485, 0.456, 0.406]
n_std = [0.229, 0.224, 0.225]

normalize = transforms.Normalize(
   mean=n_mean,
   std=n_std
)
preprocess = transforms.Compose([
   transforms.Resize((224,224)),
   transforms.ToTensor(),
   normalize
])

# Display the image we will use.
response = requests.get(IMG_URL)
img_pil = Image.open(io.BytesIO(response.content))
imshow(img_pil);

# %%
img_tensor = preprocess(img_pil)
net = net.eval()
logit = net(img_tensor.unsqueeze(0))

# %%
logit.shape
# Out:
# torch.Size([1, 1000])

# %%
img_tensor.shape
# Out:
# torch.Size([3, 224, 224])

# %%
# download the imagenet category list
classes = {int(key):value for (key, value)
          in requests.get(LABELS_URL).json().items()}


def print_preds(logit):
    # print the predicitions with their 'probabilities' from the logit
    h_x = F.softmax(logit, dim=1).data.squeeze()
    probs, idx = h_x.sort(0, True)
    probs = probs.numpy()
    idx = idx.numpy()
    # output the prediction
    for i in range(0, 5):
        print('{:.3f} -> {}'.format(probs[i], classes[idx[i]]))
    return idx

# %%
idx = print_preds(logit)
# Out:
# 0.221 -> lakeside, lakeshore
# 0.180 -> alp
# 0.159 -> mountain bike, all-terrain bike, off-roader
# 0.082 -> seashore, coast, seacoast, sea-coast
# 0.058 -> worm fence, snake fence, snake-rail fence, Virginia fence

# %%
def returnCAM(feature_conv, idx):
    # input: tensor feature_conv of dim 1000*W*H and idx between 0 and 999
    # output: image W*H with entries rescaled between 0 and 255 for the display
    cam = feature_conv[idx].detach().numpy()
    cam = cam - np.min(cam)
    cam_img = cam / np.max(cam)
    cam_img = np.uint8(255 * cam_img)
    return cam_img

# %%
#some utilities
def pil_2_np(img_pil):
    # transform a PIL image in a numpy array
    return np.asarray(img_pil)

def display_np(img_np):
    imshow(Image.fromarray(np.uint8(img_np)))
    
def plot_CAM(img_np, CAM):
    height, width, _ = img_np.shape
    heatmap = cv2.applyColorMap(cv2.resize(CAM,(width, height)), cv2.COLORMAP_JET)
    result = heatmap * 0.3 + img_np * 0.5
    display_np(result)

# %%
# here is a fake example to see how things work
img_np = pil_2_np(img_pil)
diag_CAM = returnCAM(torch.eye(7).unsqueeze(0),0)
plot_CAM(img_np,diag_CAM)

# %%
# your code here for your new network
net_conv = nn.Sequential(*list(net.children())[:-2], nn.Conv2d(512, 1000, 1))

net_conv[-1].weight[:, :, 0, 0] = net.fc.weight
net_conv[-1].bias = net.fc.bias

# do not forget:
net_conv = net_conv.eval()

# %%
# to test things are right
x = torch.randn(5, 3, 224, 224)
y = net_conv(x)
y.shape
# Out:
# torch.Size([5, 1000, 7, 7])

# %%
logit_conv = net_conv(img_tensor.unsqueeze(0))

# %%
logit_conv.shape
# Out:
# torch.Size([1, 1000, 7, 7])

# %%
# transfor this to a [1,1000] tensor with AdaptiveAvgPool2d
m = nn.AdaptiveAvgPool2d((1,1))
logit_new = m(logit_conv[0])[:, 0].T
logit_new.shape
# Out:
# torch.Size([1, 1000])

# %%
idx = print_preds(logit_new)
# Out:
# 0.221 -> lakeside, lakeshore
# 0.180 -> alp
# 0.159 -> mountain bike, all-terrain bike, off-roader
# 0.082 -> seashore, coast, seacoast, sea-coast
# 0.058 -> worm fence, snake fence, snake-rail fence, Virginia fence

# %%
i = 0#index of lakeside
CAM1 = returnCAM(logit_conv.squeeze(),idx[i])
plot_CAM(img_np,CAM1)

# %%
i = 2#index of mountain bike
CAM2 = returnCAM(logit_conv.squeeze(),idx[i])
plot_CAM(img_np,CAM2)

# %% [markdown]
# # 2- Adversarial examples

# %% [markdown]
# In this second part, we will look at [adversarial examples](https://arxiv.org/abs/1607.02533): "An adversarial example is a sample of input data which has been modified very slightly in a way that is intended to cause a machine learning classifier to misclassify it. In many cases, these modifications can be so subtle that a human observer does not even notice the modification at all, yet the classifier still makes a mistake. Adversarial examples pose security concerns because they could be used to perform an attack on machine learning systems..."
#
# Rules of the game:
# - the attacker cannot modify the classifier, i.e. the neural net with the preprocessing done on the image before being fed to the network.
# - even if the attacker cannot modifiy the classifier, we assume that the attacker knows the architecture of the classifier. Here, we will still work with `resnet18` and the standard Imagenet normalization.
# - the attacker can only modify the physical image fed into the network.
# - the attacker should fool the classifier, i.e. the label obtained on the corrupted image should not be the same as the label predicted on the original image.
#
# First, you will implement *Fast gradient sign method (FGSM)* wich is described in Section 2.1 of [Adversarial examples in the physical world](https://arxiv.org/abs/1607.02533). The idea is simple, suppose you have an image $\mathbf{x}$ and when you pass it through the network, you get the 'true' label $y$. You know that your network has been trained by minimizing the loss $J(\mathbf{\theta}, \mathbf{x}, y)$ with respect to the parameters of the network $\theta$. Now, $\theta$ is fixed as you cannot modify the classifier so you need to modify $\mathbf{x}$. In order to do so, you can compute the gradient of the loss with respect to $\mathbf{x}$ i.e. $\nabla_{\mathbf{x}} J(\mathbf{\theta}, \mathbf{x}, y)$ and use it as follows to get the modified image $\tilde{\mathbf{x}}$:
# $$
# \tilde{\mathbf{x}} = \text{Clamp}\left(\mathbf{x} + \epsilon *
# \text{sign}(\nabla_{\mathbf{x}} J(\mathbf{\theta}, \mathbf{x}, y)),0,1\right),
# $$
# where $\text{Clamp}(\cdot, 0,1)$ ensures that $\tilde{\mathbf{x}}$ is a proper image.
# Note that if instead of sign, you take the full gradient, you are now following the gradient i.e. increasing the loss $J(\mathbf{\theta}, \mathbf{x}, y)$ so that $y$ becomes less likely to be the predicited label.

# %% [markdown]
# ## Validation:
# 1. Implement this attack. Make sure to display the corrupted image.
#
# 2. For what value of epsilon is your attack successful? What is the predicited class then?
#
# The attack is successful for any value of $\epsilon > 1.43 \cdot 10^{-3}$. When $\epsilon \approx 1.43 \cdot 10^{-3}$ the predicted class is "Barrel, Cask", when $\epsilon \gg 1.43 \cdot 10^{-3}$ the predicted class is: "Hay".
#
# 3. plot the sign of the gradient and pass this image through the network. What prediction do you obtain? Compare to [Explaining and Harnessing Adversarial Examples](https://arxiv.org/abs/1412.6572)
#
# We obtain the class: "nematode, nematode worm, roundworm" just like in the paper but with a much higher confidence.

# %%
# Image under attack!
url_car = 'https://cdn130.picsart.com/263132982003202.jpg?type=webp&to=min&r=640'
response = requests.get(url_car)
img_pil = Image.open(io.BytesIO(response.content))
imshow(img_pil);

# %%
# same as above
preprocess = transforms.Compose([
   transforms.Resize((224,224)),
   transforms.ToTensor(),
   normalize
])

for p in net.parameters():
    p.requires_grad = False
    
x = preprocess(img_pil).clone().unsqueeze(0)
logit = net(x)

# %%
_ = print_preds(logit)
# Out:
# 0.641 -> minivan
# 0.043 -> jeep, landrover
# 0.032 -> beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon
# 0.021 -> sports car, sport car
# 0.020 -> pickup, pickup truck

# %%
t_std = torch.from_numpy(np.array(n_std, dtype=np.float32)).view(-1, 1, 1)
t_mean = torch.from_numpy(np.array(n_mean, dtype=np.float32)).view(-1, 1, 1)

def plot_img_tensor(img):
    imshow(np.transpose(img.detach().numpy(), [1,2,0]))

def plot_untransform(x_t): 
    x_np = (x_t * t_std + t_mean).detach().numpy()
    x_np = np.transpose(x_np, [1, 2, 0])
    imshow(x_np)

# %%
# here we display an image given as a tensor
x_img = (x * t_std + t_mean).squeeze(0)
plot_img_tensor(x_img)

# %%
# your implementation of the attack
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    grad_sign = torch.sign(data_grad)
    
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*grad_sign
    
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    
    # Return the perturbed image
    return perturbed_image

# %%
idx = 656 #minivan
criterion = nn.CrossEntropyLoss()
x_img.requires_grad = True
logit = net(normalize(x_img).unsqueeze(0))
target = torch.tensor([idx])

    #TODO: compute the loss to backpropagate

net.zero_grad()
loss = criterion(logit, target)
loss.backward()
nabla = x_img.grad

_ = print_preds(logit)
# Out:
# 0.641 -> minivan
# 0.043 -> jeep, landrover
# 0.032 -> beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon
# 0.021 -> sports car, sport car
# 0.020 -> pickup, pickup truck

# %%
epsilontab = [1e-10, 1e-4, 1e-3, 1.43 * 1e-3, 1e-2, 1e-1]
# your attack here
for epsilon in epsilontab:
    print('Episilon = ', epsilon)
    x_att = fgsm_attack(x_img,epsilon,nabla)
    # the new prediction for the corrupted image
    logit = net(normalize(x_att).unsqueeze(0))
    _ = print_preds(logit)
    # can you see the difference?
    plot_img_tensor(x_att)
    plt.show()
    # do not forget to plot the sign of the gradient
    gradient = nabla.sign()
    plot_img_tensor((1+gradient)/2)
    plt.show()
    # what is the prediction for the gradient? 
    logit = net(normalize(gradient).unsqueeze(0))
    _ = print_preds(logit)
# Out:
# Episilon =  1e-10
# 0.641 -> minivan
# 0.043 -> jeep, landrover
# 0.032 -> beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon
# 0.021 -> sports car, sport car
# 0.020 -> pickup, pickup truck
# 0.999 -> nematode, nematode worm, roundworm
# 0.001 -> microphone, mike
# 0.000 -> wine bottle
# 0.000 -> maze, labyrinth
# 0.000 -> honeycomb
# Episilon =  0.0001
# 0.567 -> minivan
# 0.050 -> jeep, landrover
# 0.034 -> beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon
# 0.025 -> sports car, sport car
# 0.025 -> pickup, pickup truck
# 0.999 -> nematode, nematode worm, roundworm
# 0.001 -> microphone, mike
# 0.000 -> wine bottle
# 0.000 -> maze, labyrinth
# 0.000 -> honeycomb
# Episilon =  0.001
# 0.126 -> minivan
# 0.069 -> jeep, landrover
# 0.050 -> barrel, cask
# 0.046 -> pickup, pickup truck
# 0.041 -> sports car, sport car
# 0.999 -> nematode, nematode worm, roundworm
# 0.001 -> microphone, mike
# 0.000 -> wine bottle
# 0.000 -> maze, labyrinth
# 0.000 -> honeycomb
# Episilon =  0.00143
# 0.061 -> minivan
# 0.061 -> jeep, landrover
# 0.057 -> barrel, cask
# 0.044 -> pickup, pickup truck
# 0.044 -> racer, race car, racing car
# 0.999 -> nematode, nematode worm, roundworm
# 0.001 -> microphone, mike
# 0.000 -> wine bottle
# 0.000 -> maze, labyrinth
# 0.000 -> honeycomb
# Episilon =  0.01
# 0.103 -> hay
# 0.066 -> thresher, thrasher, threshing machine
# 0.062 -> barrel, cask
# 0.052 -> racer, race car, racing car
# 0.051 -> projectile, missile
# 0.999 -> nematode, nematode worm, roundworm
# 0.001 -> microphone, mike
# 0.000 -> wine bottle
# 0.000 -> maze, labyrinth
# 0.000 -> honeycomb
# Episilon =  0.1
# 0.122 -> hay
# 0.102 -> doormat, welcome mat
# 0.045 -> wool, woolen, woollen
# 0.040 -> sock
# 0.037 -> mitten
# 0.999 -> nematode, nematode worm, roundworm
# 0.001 -> microphone, mike
# 0.000 -> wine bottle
# 0.000 -> maze, labyrinth
# 0.000 -> honeycomb

# %% [markdown]
# # 3- Transforming a car into a cat
#
# We now implement the *Iterative Target Class Method (ITCM)* as defined by equation (4) in [Adversarial Attacks and Defences Competition](https://arxiv.org/abs/1804.00097)
#
# To test it, we will transform the car (labeled minivan by our `resnet18`) into a [Tabby cat](https://en.wikipedia.org/wiki/Tabby_cat) (classe 281 in Imagenet). But you can try with any other target.

# %% [markdown]
# ## Validation:
# 1. Implement the ITCM and make sure to display the resulting image.

# %%
x = preprocess(img_pil).clone()
xd = preprocess(img_pil).clone()
xd.requires_grad = True

# %% [markdown]
# $$
# \tilde{\mathbf{x}} = Clip_{X, \varepsilon}(\tilde{\mathbf{x}} - \alpha Sign(\nabla_X J(\tilde{\mathbf{x}}, y_{target}))
# $$

# %%
idx = 281 #tabby
alpha = 0.01
epsilon = 0.1
optimizer = optim.SGD([xd], lr=0.01)

y_target = torch.tensor([idx])

for i in range(200):
    #TODO: your code here
    net.zero_grad()
    output = net(normalize(xd).unsqueeze(0))
    loss = criterion(output, y_target)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    nabla_sign = xd.grad.data.sign()
    
    
    xd.data = x.data + torch.clamp(xd.data - alpha * nabla_sign - x.data, -epsilon, epsilon)
    
    
    print(loss.item())
    
    _ = print_preds(output)
    print(i,'-----------------')
    
    h_x = F.softmax(output, dim=1).data.squeeze()
    probs, preds_idx = h_x.sort(0, True)
    
    # TODO: break the loop once we are satisfied 
    if probs[0] > 0.99 and int(preds_idx[0]) == idx:
        break
# Out:
# 11.104485511779785
# 0.146 -> theater curtain, theatre curtain
# 0.071 -> church, church building
# 0.062 -> spotlight, spot
# 0.054 -> web site, website, internet site, site
# 0.049 -> microphone, mike
# 0 -----------------
# 9.602906227111816
# 0.095 -> theater curtain, theatre curtain
# 0.055 -> spotlight, spot
# 0.053 -> church, church building
# 0.051 -> web site, website, internet site, site
# 0.049 -> mousetrap
# 1 -----------------
# 8.594797134399414
# 0.084 -> theater curtain, theatre curtain
# 0.063 -> web site, website, internet site, site
# 0.045 -> spotlight, spot
# 0.043 -> church, church building
# 0.033 -> mousetrap
# 2 -----------------
# 7.842207908630371
# 0.063 -> theater curtain, theatre curtain
# 0.052 -> web site, website, internet site, site
# 0.044 -> spotlight, spot
# 0.038 -> church, church building
# 0.036 -> mousetrap
# 3 -----------------
# 7.241356372833252
# 0.062 -> theater curtain, theatre curtain
# 0.052 -> web site, website, internet site, site
# 0.044 -> spotlight, spot
# 0.042 -> church, church building
# 0.031 -> corn
# 4 -----------------
# 6.522671699523926
# 0.047 -> theater curtain, theatre curtain
# 0.046 -> web site, website, internet site, site
# 0.036 -> spotlight, spot
# 0.033 -> corn
# 0.029 -> church, church building
# 5 -----------------
# 5.876522064208984
# 0.044 -> web site, website, internet site, site
# 0.043 -> tricycle, trike, velocipede
# 0.042 -> theater curtain, theatre curtain
# 0.035 -> spotlight, spot
# 0.032 -> church, church building
# 6 -----------------
# 5.241224765777588
# 0.047 -> tricycle, trike, velocipede
# 0.038 -> web site, website, internet site, site
# 0.032 -> theater curtain, theatre curtain
# 0.032 -> doormat, welcome mat
# 0.030 -> lighter, light, igniter, ignitor
# 7 -----------------
# 4.686959266662598
# 0.090 -> tricycle, trike, velocipede
# 0.035 -> web site, website, internet site, site
# 0.031 -> theater curtain, theatre curtain
# 0.029 -> lighter, light, igniter, ignitor
# 0.028 -> spotlight, spot
# 8 -----------------
# 4.132715225219727
# 0.083 -> tricycle, trike, velocipede
# 0.041 -> doormat, welcome mat
# 0.039 -> web site, website, internet site, site
# 0.027 -> lighter, light, igniter, ignitor
# 0.027 -> corn
# 9 -----------------
# 3.5995211601257324
# 0.139 -> tricycle, trike, velocipede
# 0.032 -> web site, website, internet site, site
# 0.032 -> doormat, welcome mat
# 0.029 -> lighter, light, igniter, ignitor
# 0.027 -> tabby, tabby cat
# 10 -----------------
# 3.1922271251678467
# 0.097 -> tricycle, trike, velocipede
# 0.054 -> doormat, welcome mat
# 0.041 -> tabby, tabby cat
# 0.036 -> web site, website, internet site, site
# 0.032 -> lighter, light, igniter, ignitor
# 11 -----------------
# 2.6897406578063965
# 0.139 -> tricycle, trike, velocipede
# 0.068 -> tabby, tabby cat
# 0.055 -> Egyptian cat
# 0.050 -> doormat, welcome mat
# 0.032 -> web site, website, internet site, site
# 12 -----------------
# 2.3992950916290283
# 0.110 -> tricycle, trike, velocipede
# 0.091 -> tabby, tabby cat
# 0.056 -> doormat, welcome mat
# 0.050 -> Egyptian cat
# 0.038 -> web site, website, internet site, site
# 13 -----------------
# 2.014624834060669
# 0.133 -> tabby, tabby cat
# 0.123 -> tricycle, trike, velocipede
# 0.095 -> Egyptian cat
# 0.063 -> doormat, welcome mat
# 0.026 -> web site, website, internet site, site
# 14 -----------------
# 1.743972659111023
# 0.175 -> tabby, tabby cat
# 0.109 -> tricycle, trike, velocipede
# 0.083 -> Egyptian cat
# 0.061 -> doormat, welcome mat
# 0.033 -> web site, website, internet site, site
# 15 -----------------
# 1.414652943611145
# 0.243 -> tabby, tabby cat
# 0.125 -> Egyptian cat
# 0.099 -> tricycle, trike, velocipede
# 0.068 -> doormat, welcome mat
# 0.021 -> lighter, light, igniter, ignitor
# 16 -----------------
# 1.220455527305603
# 0.295 -> tabby, tabby cat
# 0.122 -> Egyptian cat
# 0.085 -> tricycle, trike, velocipede
# 0.048 -> doormat, welcome mat
# 0.025 -> web site, website, internet site, site
# 17 -----------------
# 1.0281709432601929
# 0.358 -> tabby, tabby cat
# 0.118 -> Egyptian cat
# 0.086 -> tricycle, trike, velocipede
# 0.064 -> doormat, welcome mat
# 0.023 -> tiger cat
# 18 -----------------
# 0.9377683401107788
# 0.392 -> tabby, tabby cat
# 0.136 -> Egyptian cat
# 0.064 -> tricycle, trike, velocipede
# 0.042 -> doormat, welcome mat
# 0.031 -> tiger cat
# 19 -----------------
# 0.7799465656280518
# 0.458 -> tabby, tabby cat
# 0.105 -> Egyptian cat
# 0.067 -> tricycle, trike, velocipede
# 0.056 -> doormat, welcome mat
# 0.029 -> tiger cat
# 20 -----------------
# 0.7421202063560486
# 0.476 -> tabby, tabby cat
# 0.115 -> Egyptian cat
# 0.062 -> tricycle, trike, velocipede
# 0.041 -> doormat, welcome mat
# 0.035 -> tiger cat
# 21 -----------------
# 0.6110334992408752
# 0.543 -> tabby, tabby cat
# 0.108 -> Egyptian cat
# 0.051 -> tricycle, trike, velocipede
# 0.044 -> doormat, welcome mat
# 0.029 -> tiger cat
# 22 -----------------
# 0.5380523800849915
# 0.584 -> tabby, tabby cat
# 0.102 -> Egyptian cat
# 0.048 -> tricycle, trike, velocipede
# 0.037 -> tiger cat
# 0.036 -> doormat, welcome mat
# 23 -----------------
# 0.5068897008895874
# 0.602 -> tabby, tabby cat
# 0.086 -> Egyptian cat
# 0.047 -> doormat, welcome mat
# 0.034 -> tricycle, trike, velocipede
# 0.027 -> tiger cat
# 24 -----------------
# 0.49061691761016846
# 0.612 -> tabby, tabby cat
# 0.108 -> Egyptian cat
# 0.055 -> tricycle, trike, velocipede
# 0.034 -> tiger cat
# 0.026 -> doormat, welcome mat
# 25 -----------------
# 0.4080284833908081
# 0.665 -> tabby, tabby cat
# 0.067 -> Egyptian cat
# 0.047 -> doormat, welcome mat
# 0.029 -> tiger cat
# 0.026 -> tricycle, trike, velocipede
# 26 -----------------
# 0.4074562191963196
# 0.665 -> tabby, tabby cat
# 0.106 -> Egyptian cat
# 0.044 -> tricycle, trike, velocipede
# 0.032 -> tiger cat
# 0.021 -> doormat, welcome mat
# 27 -----------------
# 0.3429020941257477
# 0.710 -> tabby, tabby cat
# 0.050 -> Egyptian cat
# 0.045 -> doormat, welcome mat
# 0.027 -> tiger cat
# 0.022 -> tricycle, trike, velocipede
# 28 -----------------
# 0.3702632784843445
# 0.691 -> tabby, tabby cat
# 0.096 -> Egyptian cat
# 0.041 -> tricycle, trike, velocipede
# 0.030 -> tiger cat
# 0.017 -> doormat, welcome mat
# 29 -----------------
# 0.2769155502319336
# 0.758 -> tabby, tabby cat
# 0.045 -> Egyptian cat
# 0.037 -> doormat, welcome mat
# 0.028 -> tiger cat
# 0.017 -> tricycle, trike, velocipede
# 30 -----------------
# 0.2993430495262146
# 0.741 -> tabby, tabby cat
# 0.085 -> Egyptian cat
# 0.034 -> tricycle, trike, velocipede
# 0.028 -> tiger cat
# 0.015 -> doormat, welcome mat
# 31 -----------------
# 0.24592764675617218
# 0.782 -> tabby, tabby cat
# 0.039 -> Egyptian cat
# 0.033 -> doormat, welcome mat
# 0.025 -> tiger cat
# 0.017 -> tricycle, trike, velocipede
# 32 -----------------
# 0.24708084762096405
# 0.781 -> tabby, tabby cat
# 0.075 -> Egyptian cat
# 0.027 -> tricycle, trike, velocipede
# 0.026 -> tiger cat
# 0.015 -> doormat, welcome mat
# 33 -----------------
# 0.20265929400920868
# 0.817 -> tabby, tabby cat
# 0.031 -> Egyptian cat
# 0.029 -> doormat, welcome mat
# 0.023 -> tiger cat
# 0.014 -> tricycle, trike, velocipede
# 34 -----------------
# 0.22421404719352722
# 0.799 -> tabby, tabby cat
# 0.070 -> Egyptian cat
# 0.026 -> tiger cat
# 0.025 -> tricycle, trike, velocipede
# 0.012 -> doormat, welcome mat
# 35 -----------------
# 0.17052829265594482
# 0.843 -> tabby, tabby cat
# 0.028 -> Egyptian cat
# 0.024 -> doormat, welcome mat
# 0.021 -> tiger cat
# 0.012 -> tricycle, trike, velocipede
# 36 -----------------
# 0.2056664079427719
# 0.814 -> tabby, tabby cat
# 0.063 -> Egyptian cat
# 0.024 -> tricycle, trike, velocipede
# 0.022 -> tiger cat
# 0.011 -> doormat, welcome mat
# 37 -----------------
# 0.15175402164459229
# 0.859 -> tabby, tabby cat
# 0.025 -> Egyptian cat
# 0.023 -> doormat, welcome mat
# 0.021 -> tiger cat
# 0.011 -> tricycle, trike, velocipede
# 38 -----------------
# 0.1851944774389267
# 0.831 -> tabby, tabby cat
# 0.057 -> Egyptian cat
# 0.022 -> tricycle, trike, velocipede
# 0.020 -> tiger cat
# 0.010 -> doormat, welcome mat
# 39 -----------------
# 0.13368934392929077
# 0.875 -> tabby, tabby cat
# 0.022 -> Egyptian cat
# 0.022 -> doormat, welcome mat
# 0.019 -> tiger cat
# 0.009 -> tricycle, trike, velocipede
# 40 -----------------
# 0.17373766005039215
# 0.841 -> tabby, tabby cat
# 0.055 -> Egyptian cat
# 0.021 -> tricycle, trike, velocipede
# 0.019 -> tiger cat
# 0.008 -> doormat, welcome mat
# 41 -----------------
# 0.12297985702753067
# 0.884 -> tabby, tabby cat
# 0.021 -> Egyptian cat
# 0.019 -> doormat, welcome mat
# 0.017 -> tiger cat
# 0.008 -> tricycle, trike, velocipede
# 42 -----------------
# 0.13929420709609985
# 0.870 -> tabby, tabby cat
# 0.047 -> Egyptian cat
# 0.019 -> tiger cat
# 0.015 -> tricycle, trike, velocipede
# 0.007 -> doormat, welcome mat
# 43 -----------------
# 0.11165133118629456
# 0.894 -> tabby, tabby cat
# 0.018 -> doormat, welcome mat
# 0.018 -> Egyptian cat
# 0.016 -> tiger cat
# 0.007 -> tricycle, trike, velocipede
# 44 -----------------
# 0.1306065320968628
# 0.878 -> tabby, tabby cat
# 0.041 -> Egyptian cat
# 0.021 -> tiger cat
# 0.014 -> tricycle, trike, velocipede
# 0.007 -> doormat, welcome mat
# 45 -----------------
# 0.10402801632881165
# 0.901 -> tabby, tabby cat
# 0.017 -> Egyptian cat
# 0.016 -> doormat, welcome mat
# 0.014 -> tiger cat
# 0.007 -> tricycle, trike, velocipede
# 46 -----------------
# 0.10843554139137268
# 0.897 -> tabby, tabby cat
# 0.034 -> Egyptian cat
# 0.019 -> tiger cat
# 0.010 -> tricycle, trike, velocipede
# 0.007 -> doormat, welcome mat
# 47 -----------------
# 0.09799379110336304
# 0.907 -> tabby, tabby cat
# 0.016 -> doormat, welcome mat
# 0.015 -> Egyptian cat
# 0.014 -> tiger cat
# 0.007 -> tricycle, trike, velocipede
# 48 -----------------
# 0.11083858460187912
# 0.895 -> tabby, tabby cat
# 0.035 -> Egyptian cat
# 0.019 -> tiger cat
# 0.011 -> tricycle, trike, velocipede
# 0.006 -> doormat, welcome mat
# 49 -----------------
# 0.08941148221492767
# 0.914 -> tabby, tabby cat
# 0.015 -> doormat, welcome mat
# 0.014 -> Egyptian cat
# 0.013 -> tiger cat
# 0.006 -> tricycle, trike, velocipede
# 50 -----------------
# 0.10768002271652222
# 0.898 -> tabby, tabby cat
# 0.036 -> Egyptian cat
# 0.017 -> tiger cat
# 0.010 -> tricycle, trike, velocipede
# 0.006 -> doormat, welcome mat
# 51 -----------------
# 0.078642837703228
# 0.924 -> tabby, tabby cat
# 0.014 -> tiger cat
# 0.013 -> doormat, welcome mat
# 0.012 -> Egyptian cat
# 0.006 -> tricycle, trike, velocipede
# 52 -----------------
# 0.09604285657405853
# 0.908 -> tabby, tabby cat
# 0.033 -> Egyptian cat
# 0.015 -> tiger cat
# 0.009 -> tricycle, trike, velocipede
# 0.005 -> doormat, welcome mat
# 53 -----------------
# 0.06925827264785767
# 0.933 -> tabby, tabby cat
# 0.013 -> tiger cat
# 0.011 -> doormat, welcome mat
# 0.010 -> Egyptian cat
# 0.005 -> tricycle, trike, velocipede
# 54 -----------------
# 0.08255881816148758
# 0.921 -> tabby, tabby cat
# 0.030 -> Egyptian cat
# 0.014 -> tiger cat
# 0.006 -> tricycle, trike, velocipede
# 0.004 -> doormat, welcome mat
# 55 -----------------
# 0.06456930935382843
# 0.937 -> tabby, tabby cat
# 0.011 -> tiger cat
# 0.010 -> doormat, welcome mat
# 0.009 -> Egyptian cat
# 0.005 -> tricycle, trike, velocipede
# 56 -----------------
# 0.0757192075252533
# 0.927 -> tabby, tabby cat
# 0.028 -> Egyptian cat
# 0.014 -> tiger cat
# 0.005 -> tricycle, trike, velocipede
# 0.004 -> doormat, welcome mat
# 57 -----------------
# 0.06108575686812401
# 0.941 -> tabby, tabby cat
# 0.011 -> tiger cat
# 0.010 -> doormat, welcome mat
# 0.008 -> Egyptian cat
# 0.004 -> tricycle, trike, velocipede
# 58 -----------------
# 0.07166799902915955
# 0.931 -> tabby, tabby cat
# 0.026 -> Egyptian cat
# 0.014 -> tiger cat
# 0.005 -> tricycle, trike, velocipede
# 0.003 -> doormat, welcome mat
# 59 -----------------
# 0.05619358643889427
# 0.945 -> tabby, tabby cat
# 0.010 -> tiger cat
# 0.009 -> Egyptian cat
# 0.008 -> doormat, welcome mat
# 0.004 -> tricycle, trike, velocipede
# 60 -----------------
# 0.060884322971105576
# 0.941 -> tabby, tabby cat
# 0.021 -> Egyptian cat
# 0.012 -> tiger cat
# 0.004 -> tricycle, trike, velocipede
# 0.003 -> doormat, welcome mat
# 61 -----------------
# 0.05029125511646271
# 0.951 -> tabby, tabby cat
# 0.010 -> tiger cat
# 0.007 -> doormat, welcome mat
# 0.007 -> Egyptian cat
# 0.003 -> tricycle, trike, velocipede
# 62 -----------------
# 0.0622575506567955
# 0.940 -> tabby, tabby cat
# 0.021 -> Egyptian cat
# 0.011 -> tiger cat
# 0.005 -> tricycle, trike, velocipede
# 0.003 -> doormat, welcome mat
# 63 -----------------
# 0.04584893584251404
# 0.955 -> tabby, tabby cat
# 0.009 -> tiger cat
# 0.008 -> Egyptian cat
# 0.006 -> doormat, welcome mat
# 0.003 -> tiger, Panthera tigris
# 64 -----------------
# 0.05122718960046768
# 0.950 -> tabby, tabby cat
# 0.016 -> Egyptian cat
# 0.010 -> tiger cat
# 0.005 -> tricycle, trike, velocipede
# 0.003 -> doormat, welcome mat
# 65 -----------------
# 0.043916452676057816
# 0.957 -> tabby, tabby cat
# 0.008 -> tiger cat
# 0.007 -> Egyptian cat
# 0.006 -> doormat, welcome mat
# 0.003 -> EntleBucher
# 66 -----------------
# 0.0578930489718914
# 0.944 -> tabby, tabby cat
# 0.019 -> Egyptian cat
# 0.010 -> tiger cat
# 0.006 -> tricycle, trike, velocipede
# 0.003 -> doormat, welcome mat
# 67 -----------------
# 0.04049059376120567
# 0.960 -> tabby, tabby cat
# 0.008 -> tiger cat
# 0.007 -> Egyptian cat
# 0.005 -> doormat, welcome mat
# 0.003 -> tiger, Panthera tigris
# 68 -----------------
# 0.04817230999469757
# 0.953 -> tabby, tabby cat
# 0.016 -> Egyptian cat
# 0.009 -> tiger cat
# 0.004 -> tricycle, trike, velocipede
# 0.002 -> doormat, welcome mat
# 69 -----------------
# 0.038419704884290695
# 0.962 -> tabby, tabby cat
# 0.008 -> tiger cat
# 0.006 -> Egyptian cat
# 0.005 -> doormat, welcome mat
# 0.002 -> EntleBucher
# 70 -----------------
# 0.04702972248196602
# 0.954 -> tabby, tabby cat
# 0.015 -> Egyptian cat
# 0.010 -> tiger cat
# 0.004 -> tricycle, trike, velocipede
# 0.002 -> doormat, welcome mat
# 71 -----------------
# 0.035655125975608826
# 0.965 -> tabby, tabby cat
# 0.007 -> tiger cat
# 0.006 -> Egyptian cat
# 0.005 -> doormat, welcome mat
# 0.002 -> tricycle, trike, velocipede
# 72 -----------------
# 0.04047204926609993
# 0.960 -> tabby, tabby cat
# 0.013 -> Egyptian cat
# 0.009 -> tiger cat
# 0.003 -> tricycle, trike, velocipede
# 0.002 -> doormat, welcome mat
# 73 -----------------
# 0.03459810093045235
# 0.966 -> tabby, tabby cat
# 0.007 -> tiger cat
# 0.006 -> Egyptian cat
# 0.005 -> doormat, welcome mat
# 0.002 -> tricycle, trike, velocipede
# 74 -----------------
# 0.04002982750535011
# 0.961 -> tabby, tabby cat
# 0.013 -> Egyptian cat
# 0.009 -> tiger cat
# 0.003 -> tricycle, trike, velocipede
# 0.002 -> tiger, Panthera tigris
# 75 -----------------
# 0.03299754112958908
# 0.968 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.005 -> doormat, welcome mat
# 0.005 -> Egyptian cat
# 0.002 -> tricycle, trike, velocipede
# 76 -----------------
# 0.038780536502599716
# 0.962 -> tabby, tabby cat
# 0.015 -> Egyptian cat
# 0.008 -> tiger cat
# 0.003 -> tricycle, trike, velocipede
# 0.002 -> tiger, Panthera tigris
# 77 -----------------
# 0.032007548958063126
# 0.968 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.005 -> doormat, welcome mat
# 0.004 -> Egyptian cat
# 0.002 -> tricycle, trike, velocipede
# 78 -----------------
# 0.037610169500112534
# 0.963 -> tabby, tabby cat
# 0.016 -> Egyptian cat
# 0.008 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> doormat, welcome mat
# 79 -----------------
# 0.030217796564102173
# 0.970 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.005 -> doormat, welcome mat
# 0.003 -> Egyptian cat
# 0.003 -> tricycle, trike, velocipede
# 80 -----------------
# 0.03456804156303406
# 0.966 -> tabby, tabby cat
# 0.014 -> Egyptian cat
# 0.007 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> doormat, welcome mat
# 81 -----------------
# 0.027213970199227333
# 0.973 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.004 -> doormat, welcome mat
# 0.003 -> Egyptian cat
# 0.002 -> tricycle, trike, velocipede
# 82 -----------------
# 0.03118055686354637
# 0.969 -> tabby, tabby cat
# 0.012 -> Egyptian cat
# 0.006 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> doormat, welcome mat
# 83 -----------------
# 0.026440240442752838
# 0.974 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.004 -> doormat, welcome mat
# 0.003 -> Egyptian cat
# 0.002 -> tiger, Panthera tigris
# 84 -----------------
# 0.031080370768904686
# 0.969 -> tabby, tabby cat
# 0.012 -> Egyptian cat
# 0.006 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> doormat, welcome mat
# 85 -----------------
# 0.025131648406386375
# 0.975 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.004 -> doormat, welcome mat
# 0.003 -> Egyptian cat
# 0.002 -> tiger, Panthera tigris
# 86 -----------------
# 0.030647268518805504
# 0.970 -> tabby, tabby cat
# 0.012 -> Egyptian cat
# 0.006 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> doormat, welcome mat
# 87 -----------------
# 0.023885129019618034
# 0.976 -> tabby, tabby cat
# 0.006 -> tiger cat
# 0.003 -> doormat, welcome mat
# 0.003 -> Egyptian cat
# 0.002 -> tiger, Panthera tigris
# 88 -----------------
# 0.029707716777920723
# 0.971 -> tabby, tabby cat
# 0.010 -> Egyptian cat
# 0.006 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> window screen
# 89 -----------------
# 0.022144779562950134
# 0.978 -> tabby, tabby cat
# 0.005 -> tiger cat
# 0.003 -> Egyptian cat
# 0.003 -> doormat, welcome mat
# 0.002 -> web site, website, internet site, site
# 90 -----------------
# 0.02803335338830948
# 0.972 -> tabby, tabby cat
# 0.009 -> Egyptian cat
# 0.007 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 91 -----------------
# 0.021096594631671906
# 0.979 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.003 -> Egyptian cat
# 0.003 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 92 -----------------
# 0.029025893658399582
# 0.971 -> tabby, tabby cat
# 0.009 -> Egyptian cat
# 0.007 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> window screen
# 93 -----------------
# 0.01976953260600567
# 0.980 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.003 -> Egyptian cat
# 0.002 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 94 -----------------
# 0.027116285637021065
# 0.973 -> tabby, tabby cat
# 0.008 -> Egyptian cat
# 0.007 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> window screen
# 95 -----------------
# 0.018956448882818222
# 0.981 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.003 -> Egyptian cat
# 0.002 -> doormat, welcome mat
# 0.001 -> tiger, Panthera tigris
# 96 -----------------
# 0.02355334721505642
# 0.977 -> tabby, tabby cat
# 0.006 -> Egyptian cat
# 0.006 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> window screen
# 97 -----------------
# 0.018121279776096344
# 0.982 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.003 -> Egyptian cat
# 0.002 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 98 -----------------
# 0.021423358470201492
# 0.979 -> tabby, tabby cat
# 0.006 -> Egyptian cat
# 0.005 -> tiger cat
# 0.002 -> tricycle, trike, velocipede
# 0.001 -> window screen
# 99 -----------------
# 0.017058318480849266
# 0.983 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.003 -> Egyptian cat
# 0.002 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 100 -----------------
# 0.019623076543211937
# 0.981 -> tabby, tabby cat
# 0.005 -> tiger cat
# 0.005 -> Egyptian cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> window screen
# 101 -----------------
# 0.016783228144049644
# 0.983 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.003 -> Egyptian cat
# 0.002 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 102 -----------------
# 0.019694145768880844
# 0.980 -> tabby, tabby cat
# 0.006 -> Egyptian cat
# 0.005 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 103 -----------------
# 0.01567976549267769
# 0.984 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.002 -> Egyptian cat
# 0.002 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 104 -----------------
# 0.020329561084508896
# 0.980 -> tabby, tabby cat
# 0.007 -> Egyptian cat
# 0.005 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 105 -----------------
# 0.015895087271928787
# 0.984 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.002 -> doormat, welcome mat
# 0.002 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 106 -----------------
# 0.0202538650482893
# 0.980 -> tabby, tabby cat
# 0.008 -> Egyptian cat
# 0.005 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 107 -----------------
# 0.014996057376265526
# 0.985 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.002 -> doormat, welcome mat
# 0.002 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 108 -----------------
# 0.01818707026541233
# 0.982 -> tabby, tabby cat
# 0.007 -> Egyptian cat
# 0.004 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 109 -----------------
# 0.014370989985764027
# 0.986 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.002 -> doormat, welcome mat
# 0.002 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 110 -----------------
# 0.016656968742609024
# 0.983 -> tabby, tabby cat
# 0.006 -> Egyptian cat
# 0.004 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 111 -----------------
# 0.013862872496247292
# 0.986 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.002 -> doormat, welcome mat
# 0.001 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 112 -----------------
# 0.01652178168296814
# 0.984 -> tabby, tabby cat
# 0.006 -> Egyptian cat
# 0.004 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 113 -----------------
# 0.012717809528112411
# 0.987 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.002 -> doormat, welcome mat
# 0.002 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 114 -----------------
# 0.016177458688616753
# 0.984 -> tabby, tabby cat
# 0.006 -> Egyptian cat
# 0.004 -> tiger cat
# 0.001 -> tricycle, trike, velocipede
# 0.001 -> tiger, Panthera tigris
# 115 -----------------
# 0.012027832679450512
# 0.988 -> tabby, tabby cat
# 0.003 -> tiger cat
# 0.002 -> doormat, welcome mat
# 0.002 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 116 -----------------
# 0.01554914005100727
# 0.985 -> tabby, tabby cat
# 0.005 -> Egyptian cat
# 0.004 -> tiger cat
# 0.001 -> tiger, Panthera tigris
# 0.001 -> tricycle, trike, velocipede
# 117 -----------------
# 0.01163223572075367
# 0.988 -> tabby, tabby cat
# 0.002 -> tiger cat
# 0.002 -> Egyptian cat
# 0.001 -> doormat, welcome mat
# 0.001 -> EntleBucher
# 118 -----------------
# 0.013770812191069126
# 0.986 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.004 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 0.001 -> tricycle, trike, velocipede
# 119 -----------------
# 0.01143697090446949
# 0.989 -> tabby, tabby cat
# 0.002 -> tiger cat
# 0.002 -> Egyptian cat
# 0.001 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 120 -----------------
# 0.013137096539139748
# 0.987 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.004 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 0.001 -> tricycle, trike, velocipede
# 121 -----------------
# 0.010699642822146416
# 0.989 -> tabby, tabby cat
# 0.002 -> tiger cat
# 0.002 -> Egyptian cat
# 0.001 -> doormat, welcome mat
# 0.001 -> web site, website, internet site, site
# 122 -----------------
# 0.011844662018120289
# 0.988 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.003 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 0.000 -> window screen
# 123 -----------------
# 0.010560227558016777
# 0.989 -> tabby, tabby cat
# 0.002 -> tiger cat
# 0.001 -> doormat, welcome mat
# 0.001 -> Egyptian cat
# 0.001 -> EntleBucher
# 124 -----------------
# 0.01222003810107708
# 0.988 -> tabby, tabby cat
# 0.004 -> tiger cat
# 0.004 -> Egyptian cat
# 0.001 -> tiger, Panthera tigris
# 0.000 -> tricycle, trike, velocipede
# 125 -----------------
# 0.009884812869131565
# 0.990 -> tabby, tabby cat
# 0.002 -> tiger cat
# 0.001 -> doormat, welcome mat
# 0.001 -> Egyptian cat
# 0.001 -> EntleBucher
# 126 -----------------

# %%
_ = print_preds(output)
# Out:
# 0.990 -> tabby, tabby cat
# 0.002 -> tiger cat
# 0.001 -> doormat, welcome mat
# 0.001 -> Egyptian cat
# 0.001 -> EntleBucher

# %%
# plot the corrupted image
plot_img_tensor(xd)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 4- Where is the cat hidden?
#
# Last, we use CAM to understand where the network see a cat in the image.

# %% [markdown]
# ## Validation:
# 1. display the CAM for the class tabby
#
# 2. display the CAM for the class minivan
#
# 3. where is the cat?
#
# The cat seems to be at the back of the car. Maybe it's hidden in the trunk ? :O We have to save the cat !

# %%
idx_tabby, idx_minivan = 281, 656

logit_fgsm = net_conv(normalize(xd).unsqueeze(0))

CAM = returnCAM(logit_fgsm.squeeze(), idx_tabby)
plot_CAM(pil_2_np(img_pil),CAM)

# %%
CAM = returnCAM(logit_fgsm.squeeze(), idx_minivan)
plot_CAM(pil_2_np(img_pil),CAM)
