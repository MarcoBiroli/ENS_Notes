# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

import math
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1

# %%
plt.close('all')
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sin(X** 2 + Y** 2)-.75
plt.figure()
contour = plt.contour(X, Y, Z, 10, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
#contour_filled = plt.contourf(X, Y, Z, levels)
#plt.colorbar(contour_filled)
plt.title('Portrait de phase')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##Exercise 1.2.a

def solve_ode(uinit1,uinit2,a,b):
    def deriv(u,t):
        return np.array([u[1],-a*u[1]-b*np.sin(u[0])])
    time=np.linspace(0,20,1000)
    u=odeint(deriv,(uinit1,uinit2),time)
    x=u[:,0]
    y=u[:,1]
    axes=plt.gca()
    axes.set_xlim([-5,5])
    axes.set_ylim([-5,5])
    return plt.plot(x,y)
solve_ode(1.,1.,.1,5)
plt.show()
    
a=1
b=2
c=3
d=4
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="600">

# %%
M=[np.array([[1,2],[3,4]]),np.array([[1,-1],[2,1]]),np.array([[-1,-2],[2,-1]])]
t=np.linspace(-1,1,2000)
init_pos=[np.linspace(0,2,20),np.linspace(0,2,20)]

def matrix(A,x0,t):
    theta, theta_dot=theta_thetadot
    return odeint()


plt.figure(figsize=(6,6))
for theta_0 in theta_init:
    theta,theta_dot=odeint(simple_pendulum, (0,theta_0),t).T
    plt.plot(theta,theta_dot)
plt.axis("equal")
plt.xlim(-2*np.pi,2*np.pi)
plt.ylim(-4,4)
plt.title("diagramme de phase")
plt.tight_layout()
plt.show()

# %%
time=np.linspace(0,10,10000)
def f(X,t):
    return AX
x=odeint(f,2,time)
plt.figure()
plt.plot(time,x)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
