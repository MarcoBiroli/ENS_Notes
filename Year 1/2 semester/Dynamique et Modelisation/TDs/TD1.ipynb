# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import math
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %% [markdown]
# ## Part 1

# %% [markdown]
# This first part will consist in modelling a spinning colored oblong shape. We know that the following holds:
# $$
# z = \sin(x^2 + y^2) - 0.75
# $$
# Below we show the contour plot of $z$ in a phase diagram.

# %%
plt.close('all')
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sin(X** 2 + Y** 2)-.75
plt.figure()
contour = plt.contour(X, Y, Z, 10, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
#contour_filled = plt.contourf(X, Y, Z, levels)
#plt.colorbar(contour_filled)
plt.title('Portrait de phase')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
#plot the trajectories of the two colors
plt.close('all')

t=np.linspace(0,2*np.pi,100)

R=1.0;
L=10.0;
omegaz=1;
omegas=7;

fig3D = plt.figure()
ax = fig3D.gca(projection='3d')

X=(L/2)*np.cos(omegaz*t)-R*np.cos(math.pi/2+omegas*t)*np.sin(omegaz*t)
Y=(L/2)*np.sin(omegaz*t)+R*np.cos(math.pi/2+omegas*t)*np.cos(omegaz*t)
Z=R*(1+np.sin(math.pi/2+omegas*t))
ax.plot(X, Y, Z,label='$black$',color='k')

plt.title("rouge/black")
Y=-(L/2)*np.cos(omegaz*t)-R*np.cos(math.pi/2+omegas*t)*np.sin(omegaz*t)
X=-(L/2)*np.sin(omegaz*t)+R*np.cos(math.pi/2+omegas*t)*np.cos(omegaz*t)
Z=R*(1+np.sin(math.pi/2+omegas*t))

ax.plot(X, Y, Z, label='$rouge$',color='r')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %%
#identify the points where the color is seen

t=np.arange(0,2*np.pi,2*np.pi/omegas)
Y=-(L/2)*np.cos(omegaz*t)-R*np.cos(np.pi/2+omegas*t)*np.sin(omegaz*t)
X=-(L/2)*np.sin(omegaz*t)+R*np.cos(np.pi/2+omegas*t)*np.cos(omegaz*t)

X1=(L/2)*np.cos(omegaz*t)-R*np.cos(np.pi/2+omegas*t)*np.sin(omegaz*t)
Y1=(L/2)*np.sin(omegaz*t)+R*np.cos(np.pi/2+omegas*t)*np.cos(omegaz*t)
fig=plt.figure()
plt.scatter(X, Y, label='$M_1$')
#plt.scatter(X1, Y1, label='$M_2$')

plt.title("black/rouge")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.5333333333333">

# %% [markdown]
# ## Part 2

# %% [markdown]
# We want to model the system $\dot{X}=\mu X-X^3$. When we have $\dot{x}(t)=f(x(t))$, we have that fixed points are given for
# $f(x(t))=0$. In our case we have that $\mu X-X^3=0\Rightarrow X=0\vee X=\pm\sqrt{\mu}$. Then we study their stability for fixed $\mu$: for $X=0$ we have that
